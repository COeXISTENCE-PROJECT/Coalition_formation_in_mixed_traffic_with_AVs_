# %%
def update_trafficlight(t0,t1,ty):

    read_file_name = "../routerl/networks/two_route_trafficlight/two_route_trafficlight.net.xml"
    write_file_name = "../venv/Lib/site-packages/routerl/networks/two_route_trafficlight/two_route_trafficlight.net.xml"
    network_file_name = "../networks/two_route_trafficlight/two_route_trafficlight.net.xml"

    tllogic = []
    tllogic.append( "\t<tlLogic id=\"J2\" type=\"static\" programID=\"0\" offset=\"0\">\n")
    tllogic.append( "\t\t<phase duration=\"%s\" state=\"Gr\"/>\n"%(t1))
    tllogic.append( "\t\t<phase duration=\"%s\"  state=\"yr\"/>\n"%(ty))
    tllogic.append( "\t\t<phase duration=\"%s\" state=\"rG\"/>\n"%(t0))
    tllogic.append( "\t\t<phase duration=\"%s\"  state=\"ry\"/>\n"%(ty))
    tllogic.append( "\t</tlLogic>\n")

    with open(read_file_name, "r") as fr:
        lines = fr.readlines()
        print(lines)

    with open(write_file_name, "w") as fw:
        fw.writelines(lines[:76])
        fw.writelines(tllogic)
        fw.writelines(lines[82:])

    with open(network_file_name, "w") as fw:
        fw.writelines(lines[:76])
        fw.writelines(tllogic)
        fw.writelines(lines[82:])

# %%
t0 = 20
t1 = 30
ty = 5
update_trafficlight(t0,t1,ty)
# Out:
# ['<?xml version="1.0" encoding="UTF-8"?>\n', '\n', '<!-- generated on 2025-04-16 16:19:46 by Eclipse SUMO netedit Version 1.22.0\n', '<neteditConfiguration xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://sumo.dlr.de/xsd/neteditConfiguration.xsd">\n', '\n', '    <input>\n', '        <sumo-net-file value="C:\\Users\\Utilisateur\\Desktop\\projectrouterl\\venv\\Lib\\site-packages\\routerl\\networks\\two_route_trafficlight\\two_route_trafficlight.net.xml"/>\n', '    </input>\n', '\n', '    <output>\n', '        <output-file value="C:\\Users\\Utilisateur\\Desktop\\projectrouterl\\venv\\Lib\\site-packages\\routerl\\networks\\two_route_trafficlight\\two_route_trafficlight.net.xml"/>\n', '    </output>\n', '\n', '    <processing>\n', '        <geometry.min-radius.fix.railways value="false"/>\n', '        <geometry.max-grade.fix value="false"/>\n', '        <offset.disable-normalization value="true"/>\n', '        <lefthand value="0"/>\n', '    </processing>\n', '\n', '    <junctions>\n', '        <no-turnarounds value="true"/>\n', '        <junctions.corner-detail value="5"/>\n', '        <junctions.limit-turn-speed value="5.50"/>\n', '        <rectangular-lane-cut value="0"/>\n', '    </junctions>\n', '\n', '    <pedestrian>\n', '        <walkingareas value="0"/>\n', '    </pedestrian>\n', '\n', '</neteditConfiguration>\n', '-->\n', '\n', '<net version="1.20" junctionCornerDetail="5" limitTurnSpeed="5.50" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://sumo.dlr.de/xsd/net_file.xsd">\n', '\n', '    <location netOffset="0.00,0.00" convBoundary="0.00,0.00,300.00,100.00" origBoundary="-10000000000.00,-10000000000.00,10000000000.00,10000000000.00" projParameter="!"/>\n', '\n', '    <edge id=":J1_0" function="internal">\n', '        <lane id=":J1_0_0" index="0" speed="6.51" length="9.03" shape="92.80,98.40 95.25,98.05 97.00,97.00 98.05,95.25 98.40,92.80"/>\n', '    </edge>\n', '    <edge id=":J1_1" function="internal">\n', '        <lane id=":J1_1_0" index="0" speed="13.89" length="11.20" shape="92.80,98.40 104.00,98.40"/>\n', '    </edge>\n', '    <edge id=":J2_0" function="internal">\n', '        <lane id=":J2_0_0" index="0" speed="6.51" length="9.03" shape="201.60,92.80 201.95,95.25 203.00,97.00 204.75,98.05 207.20,98.40"/>\n', '    </edge>\n', '    <edge id=":J2_1" function="internal">\n', '        <lane id=":J2_1_0" index="0" speed="13.89" length="11.20" shape="196.00,98.40 207.20,98.40"/>\n', '    </edge>\n', '    <edge id=":J4_0" function="internal">\n', '        <lane id=":J4_0_0" index="0" speed="3.90" length="2.58" shape="98.40,0.00 98.50,-0.70 98.80,-1.20 99.30,-1.50 100.00,-1.60"/>\n', '    </edge>\n', '    <edge id=":J5_0" function="internal">\n', '        <lane id=":J5_0_0" index="0" speed="3.90" length="2.58" shape="200.00,-1.60 200.70,-1.50 201.20,-1.20 201.50,-0.70 201.60,0.00"/>\n', '    </edge>\n', '\n', '    <edge id="E0" from="J0" to="J1" priority="-1">\n', '        <lane id="E0_0" index="0" speed="13.89" length="92.80" shape="0.00,98.40 92.80,98.40"/>\n', '    </edge>\n', '    <edge id="E1" from="J1" to="J2" priority="-1">\n', '        <lane id="E1_0" index="0" speed="13.89" length="92.00" shape="104.00,98.40 196.00,98.40"/>\n', '    </edge>\n', '    <edge id="E2" from="J2" to="J3" priority="-1">\n', '        <lane id="E2_0" index="0" speed="13.89" length="92.80" shape="207.20,98.40 300.00,98.40"/>\n', '    </edge>\n', '    <edge id="E3" from="J1" to="J4" priority="-1">\n', '        <lane id="E3_0" index="0" speed="13.89" length="92.80" shape="98.40,92.80 98.40,0.00"/>\n', '    </edge>\n', '    <edge id="E4" from="J4" to="J5" priority="-1">\n', '        <lane id="E4_0" index="0" speed="13.89" length="100.00" shape="100.00,-1.60 200.00,-1.60"/>\n', '    </edge>\n', '    <edge id="E5" from="J5" to="J2" priority="-1">\n', '        <lane id="E5_0" index="0" speed="13.89" length="92.80" shape="201.60,0.00 201.60,92.80"/>\n', '    </edge> ...
